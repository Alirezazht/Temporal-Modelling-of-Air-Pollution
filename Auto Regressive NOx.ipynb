# %%
import pandas as pd
data = pd.read_excel('NOx_Process.xlsx')

T = data['NOx']
data.head()
# Out:
#    Unnamed: 0        NOx  Tempreture   Humid  Wind Speed  Wind Direction Sin  \
# 0           0  10.434783        19.0  47.125     1.87500             -0.9397
# 1           1  14.041667        20.7  45.000     2.62500              0.7660
# 2           2  12.541667        19.9  54.375     5.42857              0.4999
# 3           3   9.958333        16.6  91.250     2.87500              0.9397
# 4           4  12.916667        18.9  70.125     1.87500             -0.5000
#
#    Wind Direction COS  Pressure  RainFall
# 0           -0.342020   1011.76      0.00
# 1           -0.642788   1012.04      0.10
# 2           -0.866025   1007.88      0.61
# 3           -0.342020   1008.66     22.00
# 4            0.866025   1007.70      1.00

# %%
import pmdarima as pmd

def arimamodel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              start_p=1,
                              start_q=1,      
                              test="adf",
                              information_criterion='aic',                                    
                              trace=True)
    return autoarima_model

# %%
arima_model = arimamodel(T)
arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=2598.263, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=2805.925, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=2596.824, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2659.415, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=3240.849, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=2598.564, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2578.086, Time=0.42 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=2574.623, Time=0.57 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=2590.390, Time=0.19 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=2576.559, Time=0.72 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=2586.956, Time=0.48 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2574.933, Time=0.52 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=2584.874, Time=0.36 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=2577.275, Time=0.28 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0] intercept
# Total fit time: 4.823 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  336
# Model:               SARIMAX(3, 0, 1)   Log Likelihood               -1281.311
# Date:                Wed, 23 Feb 2022   AIC                           2574.623
# Time:                        11:11:23   BIC                           2597.525
# Sample:                             0   HQIC                          2583.752
#                                 - 336
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.3866      0.393      0.984      0.325      -0.383       1.157
# ar.L1          1.4494      0.055     26.475      0.000       1.342       1.557
# ar.L2         -0.6025      0.068     -8.828      0.000      -0.736      -0.469
# ar.L3          0.1373      0.040      3.456      0.001       0.059       0.215
# ma.L1         -0.8596      0.040    -21.513      0.000      -0.938      -0.781
# sigma2       119.8015      4.697     25.508      0.000     110.596     129.007
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1070.97
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.50   Skew:                             1.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
