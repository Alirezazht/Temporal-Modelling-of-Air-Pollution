# %%
import pandas as pd
data = pd.read_excel('PM10_Process.xlsx')

T = data['PM10']
data.head()
# Out:
#    Unnamed: 0        PM10  Tempreture   Humid  Wind Speed  Wind Direction Sin  \
# 0           0  133.916667        19.0  47.125     1.87500             -0.9397
# 1           1  147.833333        20.7  45.000     2.62500              0.7660
# 2           2  157.958333        19.9  54.375     5.42857              0.4999
# 3           3   48.708333        16.6  91.250     2.87500              0.9397
# 4           4   47.541667        18.9  70.125     1.87500             -0.5000
#
#    Wind Direction COS  Pressure  RainFall
# 0           -0.342020   1011.76      0.00
# 1           -0.642788   1012.04      0.10
# 2           -0.866025   1007.88      0.61
# 3           -0.342020   1008.66     22.00
# 4            0.866025   1007.70      1.00

# %%
import pmdarima as pmd

def arimamodel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              start_p=1,
                              start_q=1,      
                              test="adf",
                              stationary = True,
                              information_criterion='aic',
                              trace=True)
    return autoarima_model

# %%
arima_model = arimamodel(T)
arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=4191.699, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4293.877, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=4190.423, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4215.196, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4736.855, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=4191.769, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=4193.743, Time=0.16 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=4265.718, Time=0.03 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.736 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  362
# Model:               SARIMAX(1, 0, 0)   Log Likelihood               -2092.211
# Date:                Wed, 23 Feb 2022   AIC                           4190.423
# Time:                        12:47:43   BIC                           4202.098
# Sample:                             0   HQIC                          4195.064
#                                 - 362
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     70.0432     10.454      6.700      0.000      49.553      90.534
# ar.L1          0.5022      0.030     16.782      0.000       0.444       0.561
# sigma2      6127.2703    277.367     22.091      0.000    5583.640    6670.901
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):              2300.10
# Prob(Q):                              0.70   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.01   Skew:                             2.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
