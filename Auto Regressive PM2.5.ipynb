# %%
import pandas as pd
data = pd.read_excel('PM25_Process.xlsx')

T = data['TT']
data.head()
# Out:
#    Unnamed: 0         TT  Tempreture   Humid  Wind Speed  Wind Direction Sin  \
# 0           0  40.363636        19.0  47.125     1.87500             -0.9397
# 1           1  41.541667        20.7  45.000     2.62500              0.7660
# 2           2  43.416667        19.9  54.375     5.42857              0.4999
# 3           3  38.291667        16.6  91.250     2.87500              0.9397
# 4           4  23.681818        18.9  70.125     1.87500             -0.5000
#
#    Wind Direction COS  Pressure  RainFall
# 0           -0.342020   1011.76      0.00
# 1           -0.642788   1012.04      0.10
# 2           -0.866025   1007.88      0.61
# 3           -0.342020   1008.66     22.00
# 4            0.866025   1007.70      1.00

# %%
import pmdarima as pmd

def arimamodel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              start_p=1,
                              start_q=1,      
                              test="adf",
                              m = 15,
                              information_criterion='aic',
                              trace=True)
    return autoarima_model

# %%
arima_model = arimamodel(T)
arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[15] intercept   : AIC=3719.821, Time=0.72 sec
#  ARIMA(0,0,0)(0,0,0)[15] intercept   : AIC=3865.241, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[15] intercept   : AIC=3718.749, Time=0.44 sec
#  ARIMA(0,0,1)(0,0,1)[15] intercept   : AIC=3745.303, Time=0.43 sec
#  ARIMA(0,0,0)(0,0,0)[15]             : AIC=4205.269, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[15] intercept   : AIC=3716.821, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[15] intercept   : AIC=3718.748, Time=0.23 sec
#  ARIMA(1,0,0)(1,0,1)[15] intercept   : AIC=3720.747, Time=0.45 sec
#  ARIMA(2,0,0)(0,0,0)[15] intercept   : AIC=3715.432, Time=0.11 sec
#  ARIMA(2,0,0)(1,0,0)[15] intercept   : AIC=3717.392, Time=0.53 sec
#  ARIMA(2,0,0)(0,0,1)[15] intercept   : AIC=3717.388, Time=0.30 sec
#  ARIMA(2,0,0)(1,0,1)[15] intercept   : AIC=3719.388, Time=0.62 sec
#  ARIMA(3,0,0)(0,0,0)[15] intercept   : AIC=3716.959, Time=0.16 sec
#  ARIMA(2,0,1)(0,0,0)[15] intercept   : AIC=3717.157, Time=0.40 sec
#  ARIMA(1,0,1)(0,0,0)[15] intercept   : AIC=3715.886, Time=0.16 sec
#  ARIMA(3,0,1)(0,0,0)[15] intercept   : AIC=3718.892, Time=0.45 sec
#  ARIMA(2,0,0)(0,0,0)[15]             : AIC=3770.905, Time=0.05 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[15] intercept
# Total fit time: 5.156 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:               SARIMAX(2, 0, 0)   Log Likelihood               -1853.716
# Date:                Wed, 23 Feb 2022   AIC                           3715.432
# Time:                        11:24:34   BIC                           3731.032
# Sample:                             0   HQIC                          3721.632
#                                 - 365
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     27.4290      4.664      5.880      0.000      18.287      36.571
# ar.L1          0.6363      0.027     23.348      0.000       0.583       0.690
# ar.L2         -0.0961      0.034     -2.839      0.005      -0.162      -0.030
# sigma2      1507.5653     35.676     42.258      0.000    1437.642    1577.488
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             32577.80
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.90   Skew:                             4.91
# Prob(H) (two-sided):                  0.00   Kurtosis:                        48.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
